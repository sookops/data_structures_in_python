# %% [markdown]
# <a href="https://colab.research.google.com/github/sookops/data_structures_in_python/blob/main/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
print(233423*233)
# Out:
# Hello
# 54387559

# %% [markdown]
# **최초의 파이썬 코드**

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

# 사용자로부터 숫자를 입력받습니다
try:
    user_input = input("소수인지 판별할 숫자를 입력하세요: ")
    number = int(user_input)

    if is_prime(number):
        print(f"{number}는 소수입니다.")
    else:
        print(f"{number}는 소수가 아닙니다.")
except ValueError:
    print("올바른 정수를 입력해 주세요.")
# Out:
# 소수인지 판별할 숫자를 입력하세요: 457
# 457는 소수입니다.

# %% [markdown]
# **AI**를 사용하여 만든 **소수**를 판별하는 프로그램
